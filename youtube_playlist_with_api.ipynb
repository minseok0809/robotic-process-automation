# %% [markdown]
# ## Youtebe Playlist with Youtube API Key

# %%
! pip install --upgrade google-api-python-client

# %%
! pip install oauth2client

# %%
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
from oauth2client.tools import argparser

# %%
DEVELOPER_KEY='AIzaSyBTMUo7SX-TopD3URMW1ngQJvDxlRYpUho'
YOUTUBE_API_SERVICE_NAME='youtube'
YOUTUBE_API_VERSION='v3'

youtube=build(YOUTUBE_API_SERVICE_NAME,YOUTUBE_API_VERSION,developerKey=DEVELOPER_KEY)

# %%
search_response=youtube.search().list(
    q="생활코딩",
    order='relevance',
    part='snippet',
    maxResults=100,
    ).execute()

# %%
channel_id=search_response['items'][0]['id']['channelId']

playlists=youtube.playlists().list(
    channelId=channel_id,
    part='snippet',
    maxResults=100).execute()

# %%
import pandas as pd

ids=[]
titles=[]
for i in playlists['items']:
    ids.append(i['id'])
    titles.append(i['snippet']['title'])
    
df=pd.DataFrame([ids,titles]).T
df.columns=['PlayLists','Titles']
df
# Out:
#                              PlayLists                                  Titles
# 0   PLuHgQVnccGMCdgkWNDsaMzPnP8YbHroiq                           웹개발자도구 shorts
# 1   PLuHgQVnccGMCiI0Fd6-LMjKtWH9MvSQNb                              GIT Shorts
# 2   PLuHgQVnccGMCzI03vlbzVFTP_kDfFGsFV                             BASH Shorts
# 3   PLuHgQVnccGMD-XRW1zlqC7U2uCzOxyT8u         Visual Studio Code에서 GIT으로 협업하기
# 4   PLuHgQVnccGMDvLEhqKQHhHxssO9I1hxsR                             생활코딩 shorts
# 5   PLuHgQVnccGMCVyDPCW8_gXhxuAo44obWW                                  SQLite
# 6   PLuHgQVnccGMClNOIuT3b3M4YZjxmult2y              Python Flask Web Framework
# 7   PLuHgQVnccGMCOGstdDZvH41x0Vtvwyxu7                          React 2022 개정판
# 8   PLuHgQVnccGMBVQ4ZcIRmcOeu8uktUAbxI   JavaScript Promise (callback & async)
# 9   PLuHgQVnccGMDLp4GH-rgQhVKqqZawlNwG             Python Django Web Framework
# 10  PLuHgQVnccGMAQvSVKdXFiOo51HUD8iQQm            Visual Studio Code 로 다루는 Git
# 11  PLuHgQVnccGMA4Lx_OpWffpPpfhNYrRpEA                                   short
# 12  PLuHgQVnccGMDeMJsGq2O-55Ymtx0IdKWf                       생활코딩 Docker 입구 수업
# 13  PLuHgQVnccGMA4ZgmqgKZhY9X39Ew8O9k5                              Python 제어문
# 14  PLuHgQVnccGMDtnr4nTSFfmocHL5FeH1xR                        생활코딩 Python 입문수업
# 15  PLuHgQVnccGMCEvYJCyey1AlwT1yyBZK6c                                   p5.js
# 16  PLuHgQVnccGMCakV9WLjnmJowCj4nvnhzv            TensorFlow.js Classification
# 17  PLuHgQVnccGMBEbPiaGs2kfQFpMmQchM-1                           Tensorflow.js
# 18  PLuHgQVnccGMAMjC3Epa9oyF7ciAtX83o7                          AWS Serverless
# 19  PLuHgQVnccGMD-9lk4xmb6EG1XK1OmwC3u                               생활코딩 암호학1
# 20  PLuHgQVnccGMBXv1OKe3Hn3Jq6F735-uWm               Github.com - Pull request
# 21  PLuHgQVnccGMAfu6PEDLIv6EeToHdTQ4wY                 Teachable machine & WEB
# 22  PLuHgQVnccGMCIA_MXFcS-IWrqKnx62Iwp                            Orange3 지도학습
# 23  PLuHgQVnccGMDy5oF7G5WYxLF3NCYhB9H9                      Machine learning 1
# 24  PLuHgQVnccGMAwnfp3Ml-XY1WNx1MPgrQ4                                Orange 3
# 25  PLuHgQVnccGMCrFJLxpjhE0N5tvOVxJuVB                                 Java 예외
# 26  PLuHgQVnccGMDiv-rCwlN-YjLKWR6-SBbM                          Java Interface
# 27  PLuHgQVnccGMA1bRSk_SZrXMngx5iq03cc                                 Java 상속
# 28  PLuHgQVnccGMCD1zZNtEfdljrtoZIL4CaA                                Airtable
# 29  PLuHgQVnccGMDWjb0TWItMCfDWDs8Y3Oo7                              Github.com
# 30  PLuHgQVnccGMCEfBwnNGsJCQDiqSWI-edj           React class vs function style
# 31  PLuHgQVnccGMB4krR04ug5nEXJ3sAEOWDL                             NPM Package
# 32  PLuHgQVnccGMChcT9IKopFDoAIoTA-03DA                                 Webpack
# 33  PLuHgQVnccGMDVTrQYa2HRj1OBbT-4HU_v                              React-Ajax
# 34  PLuHgQVnccGMDuVdsGtH1_452MtRxALb_7                             React Redux
# 35  PLuHgQVnccGMAb-e41kXPSIpmoz1RvHyN4                         JAVA 객체지향 프로그래밍
# 36  PLuHgQVnccGMDkdt3N9tT0aZPZx5-Ri2jo                             JAVA method
# 37  PLuHgQVnccGMCoEXnWV8-UF1mBxK5ftmxH                                JAVA 제어문
# 38  PLuHgQVnccGMAIluRRVsC1e79ri-dwnBmR                                   JAVA1
# 39  PLuHgQVnccGMB5q5uJIDhLlcC2V6tyXhY6                         Oracle Database
# 40  PLuHgQVnccGMDF6rHsY9qMuJMd295Yk4sa                             관계형 데이터 모델링
# 41  PLuHgQVnccGMAG1O1BRZCT3wkD_aPmPylq                                SQL JOIN
# 42  PLuHgQVnccGMB-iGMgONoRPArZfjRuRNVc                                   Redux
# 43  PLuHgQVnccGMBxNK38TqfBWk-QpEI7UkY8                 JavaScript Immutability
# 44  PLuHgQVnccGMCGGL_s6f0FpOwkXw0lmifd                              Coding.log
# 45  PLuHgQVnccGMCRv6f8H9K5Xwsdyg4sFSdi                                   React
# 46  PLuHgQVnccGMAMctarDlPyv6upFUUnpSO3  JavaScript Object Oriented Programming
# 47  PLuHgQVnccGMCwEXgZ-dep4SJlGEuYip-6                                    NPM1
# 48  PLuHgQVnccGMAp9YSO2J5VBWLJewTPn_0_                           AWS - Educate
# 49  PLuHgQVnccGMAvTJlPGzizAkyqXfZ9IyY8                   GIT4 - reset & revert

# %%
#영상 list
dtcu="PLuHgQVnccGMBT57a9dvEtd6OuWpugF9SH"
#dtcu=df['PlayLists'][0]
playlist_videos=youtube.playlistItems().list(
    playlistId=dtcu,
    part='snippet',
    maxResults=100)

playlistitems_list_response=playlist_videos.execute()

video_names=[]
video_ids=[]
date=[]

for v in playlistitems_list_response['items']:
    video_names.append(v['snippet']['title'])
    video_ids.append(v['snippet']['resourceId']['videoId'])
    date.append(v['snippet']['publishedAt'])
    
vdf=pd.DataFrame([date,video_names,video_ids]).T
vdf.columns=['Date','Title','IDS']
vdf
# Out:
#                     Date                                              Title  \
# 0   2016-11-23T14:56:20Z                           Linux - install : cloud9
# 1   2016-11-23T14:56:20Z                     Linux - install : OSX terminal
# 2   2016-11-23T14:50:39Z                         Linux - file & directory 1
# 3   2016-11-23T14:50:39Z                         Linux - file & directory 2
# 4   2016-11-23T14:50:38Z                               Linux - --help & man
# 5   2016-11-23T14:56:20Z                                  Linux - Searching
# 6   2016-11-24T11:57:21Z                       Linux - frequency of command
# 7   2016-11-23T14:56:20Z                                        Linux -sudo
# 8   2016-11-23T14:56:20Z                           Linux - file edit (nano)
# 9   2016-11-24T11:57:21Z                            Linux - Package manager
# 10  2016-11-24T15:47:40Z                       Linux - file download : wget
# 11  2016-11-24T15:47:45Z                     Linux - Source download  : git
# 12  2016-11-25T03:50:01Z              Linux - Why using CLI? 1 - GUI VS CLI
# 13  2016-11-25T03:50:01Z  Linux - Why using CLI? -sequence execution (se...
# 14  2016-11-25T03:50:01Z                  Linux - Why using CLI? (pipeline)
# 15  2016-11-26T01:36:28Z                  Linux - IO Redirection1 :  output
# 16  2016-11-26T01:36:28Z                   Linux - IO Redirection2 :  input
# 17  2016-11-26T01:36:28Z                   Linux - IO Redirection3 : append
# 18  2016-11-27T13:34:08Z                            Linux - Shell 1 : intro
# 19  2016-11-27T13:34:08Z                      Linux - Shell 2 : bash vs zsh
# 20  2016-11-27T13:34:08Z                     Linux - Shell script 1 : intro
# 21  2016-11-27T13:34:08Z                   Linux - Shell script 2 : example
# 22  2016-11-27T16:00:32Z                      Linux - Directory structure 2
# 23  2016-11-27T16:00:32Z                      Linux - Directory structure 1
# 24  2016-11-28T03:55:10Z            Linux - Process 1 :  Computer structure
# 25  2016-11-28T03:55:14Z                   Linux - Process 2 :  ps top htop
# 26  2016-11-28T23:20:19Z                 Linux - File find 1: locate,  find
# 27  2016-11-28T23:20:22Z               Linux - File find 2 : whereis, $PATH
# 28  2016-11-29T13:57:21Z             Linux - background execute (Ctrl+Z, &)
# 29  2016-11-29T13:57:27Z                            Linux - daemon 1: intro
# 30  2016-11-29T13:57:31Z            Linux - daemon 2 : service & auto start
# 31  2016-11-29T16:18:44Z     Linux - Time based job schedule cron 1 : usage
# 32  2016-11-29T16:18:44Z   Linux - Time based job schedule cron 2 : example
# 33  2016-12-01T16:39:41Z                     Linux - Startup script  bashrc
# 34  2016-12-02T15:10:04Z                        Linux - Mult user 1 : intro
# 35  2016-12-02T15:10:04Z                      Linux - Mult user 2 : id, who
# 36  2016-12-02T15:10:04Z                                  Linux - Root user
# 37  2016-12-02T15:10:04Z                                   Linux - Add user
# 38  2016-12-05T07:55:29Z                       Linux - Permission 1 : basic
# 39  2016-12-05T07:55:29Z                       Linux - Permission 2 : chmod
# 40  2016-12-05T07:55:29Z                     Linux - Permission 3 : execute
# 41  2016-12-05T07:55:29Z                   Linux - Permission 4 : directory
# 42  2016-12-05T07:55:29Z           Linux - Permission 5 : class & operation
# 43  2016-12-05T07:55:29Z                            Linux - group 1 : intro
# 44  2016-12-05T07:55:29Z                         Linux - group 2 : groupadd
# 45  2016-12-08T15:52:14Z                                 Linux - Internet 1
# 46  2016-12-08T15:52:14Z                                 Linux - internet 2
# 47  2016-12-09T02:15:26Z             Linux - web server 1 (apache) :  intro
# 48  2016-12-09T02:15:26Z            Linux - web server 2 (apache) : install
# 49  2016-12-09T02:15:26Z      Linux - web server 3 (apache) : configuration
#
#             IDS
# 0   DsG-JWrFJTc
# 1   -lcebXBCa8A
# 2   JGZxJKiFLDY
# 3   WyAuZDZoKac
# 4   ckX-2c70WUA
# 5   bX6YA-DAz_U
# 6   6DbqFPw78cc
# 7   X7kAUlbZV4Q
# 8   JIQXgPEX5Bs
# 9   mPkFqp2m8BM
# 10  zYhZ-zyteGs
# 11  v8WE_MbCjOU
# 12  uqiHrVAp2ow
# 13  nCi2QYbNow4
# 14  jiNfAQRJuRs
# 15  kpcEoSiMgnU
# 16  pagAkhHpzQk
# 17  l39yXacR1_s
# 18  HYQ65yUlJDg
# 19  VNF3BAEIUYs
# 20  cXnVygkAg4I
# 21  HZfaBDM3EW0
# 22  XLPDhl3rTFY
# 23  0MnJuI0CfIw
# 24  mrOxyFzD8SY
# 25  6anZhqAAaQk
# 26  3Ka00g1WXok
# 27  0EBdbotk-7k
# 28  ZL4qFGf1z_4
# 29  oWa3rPxxRTw
# 30  _r5neSNEO98
# 31  9SQjQthIvnE
# 32  CCViY87_OS4
# 33  kzEzUhGNMoQ
# 34  pZLb5L2pn4w
# 35  iDtwm4AeOiA
# 36  uOxHwTGjU7Q
# 37  9wXRU_61Ti8
# 38  VJCQR1j7hVw
# 39  xf9qBM26rK8
# 40  H7rCftnP0Lk
# 41  ZulvHHegNV4
# 42  BDKCPYOxZd8
# 43  4KYSoiuGd0I
# 44  tqOoh_loR2E
# 45  9K-xKrYwhVQ
# 46  SZjlQbQJOWY
# 47  wTLDvzzBrVg
# 48  1HbSglUlFd0
# 49  XmbQgFUC1Ug

# %%
pd.DataFrame(vdf['Title'])
# Out:
#                                                 Title
# 0                            Linux - install : cloud9
# 1                      Linux - install : OSX terminal
# 2                          Linux - file & directory 1
# 3                          Linux - file & directory 2
# 4                                Linux - --help & man
# 5                                   Linux - Searching
# 6                        Linux - frequency of command
# 7                                         Linux -sudo
# 8                            Linux - file edit (nano)
# 9                             Linux - Package manager
# 10                       Linux - file download : wget
# 11                     Linux - Source download  : git
# 12              Linux - Why using CLI? 1 - GUI VS CLI
# 13  Linux - Why using CLI? -sequence execution (se...
# 14                  Linux - Why using CLI? (pipeline)
# 15                  Linux - IO Redirection1 :  output
# 16                   Linux - IO Redirection2 :  input
# 17                   Linux - IO Redirection3 : append
# 18                            Linux - Shell 1 : intro
# 19                      Linux - Shell 2 : bash vs zsh
# 20                     Linux - Shell script 1 : intro
# 21                   Linux - Shell script 2 : example
# 22                      Linux - Directory structure 2
# 23                      Linux - Directory structure 1
# 24            Linux - Process 1 :  Computer structure
# 25                   Linux - Process 2 :  ps top htop
# 26                 Linux - File find 1: locate,  find
# 27               Linux - File find 2 : whereis, $PATH
# 28             Linux - background execute (Ctrl+Z, &)
# 29                            Linux - daemon 1: intro
# 30            Linux - daemon 2 : service & auto start
# 31     Linux - Time based job schedule cron 1 : usage
# 32   Linux - Time based job schedule cron 2 : example
# 33                     Linux - Startup script  bashrc
# 34                        Linux - Mult user 1 : intro
# 35                      Linux - Mult user 2 : id, who
# 36                                  Linux - Root user
# 37                                   Linux - Add user
# 38                       Linux - Permission 1 : basic
# 39                       Linux - Permission 2 : chmod
# 40                     Linux - Permission 3 : execute
# 41                   Linux - Permission 4 : directory
# 42           Linux - Permission 5 : class & operation
# 43                            Linux - group 1 : intro
# 44                         Linux - group 2 : groupadd
# 45                                 Linux - Internet 1
# 46                                 Linux - internet 2
# 47             Linux - web server 1 (apache) :  intro
# 48            Linux - web server 2 (apache) : install
# 49      Linux - web server 3 (apache) : configuration

# %% [markdown]
# ### Reference

# %% [markdown]
# [파이썬- 유튜브 API를 활용해 유튜브 데이터 크롤링하기 (Naver Blog natural)](https://blog.naver.com/leenk1006/222454926151)
