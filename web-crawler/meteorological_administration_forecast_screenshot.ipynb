# %% [markdown]
# ## Meteorological Administration Forecast Screenshot

# %% [markdown]
# <br>

# %% [markdown]
# ### Development Environment

# %%
pip install selenium

# %%
import cv2
import time
import webbrowser
from selenium import webdriver
import matplotlib
import matplotlib.pyplot as plt

# %% [markdown]
# ### Meteorological Administration Forecast

# %%
wd = webdriver.Chrome()
url = 'https://www.weather.go.kr/w/weather/forecast/short-term.do'
wd.get(url)
time.sleep(3)
wd.save_screenshot('forecast.png')
wd.quit()
img1_path = 'forecast.png'
img1_orig = cv2.imread(img1_path) 
img1_orig = img1_orig[0:img1_orig.shape[1]-90, 0:img1_orig.shape[0]]

hotrizontal_ratio = img1_orig.shape[0] / 50
vertical_ratio = img1_orig.shape[1] / 50

plt.figure(figsize=(hotrizontal_ratio, vertical_ratio))
plt.imshow(cv2.cvtColor(img1_orig, cv2.COLOR_BGR2RGB), interpolation='nearest', aspect='auto')
ax = plt.gca()
ax.axes.xaxis.set_visible(False)
ax.axes.yaxis.set_visible(False)
plt.show()

# %% [markdown]
# ### Reference

# %% [markdown]
# <b>Wikidocs</b>
# <br>[토닥토닥 파이썬 04 웹 브라우저 화면 캡처](https://wikidocs.net/48464)
# <br><br><b>기상청</b>
# <br>[날씨누리 단기예보](https://www.weather.go.kr/w/weather/forecast/short-term.do)
